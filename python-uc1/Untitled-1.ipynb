# %% [markdown]
# # Aula 04 17/08/26

# %% [markdown]
# ## My book

# %%
my_book ='Python para iniciantes'
print(my_book)
# Out:
# Python para iniciantes

# %%
my_book='Hello_world'
print(my_book)
# Out:
# Hello_world

# %%
my_book=30

# %%
gravidade = 9.8
type(gravidade)
# Out:
# float

# %%
pi =3,14
type(pi)
# Out:
# tuple

# %%
nome = input('Qual o seu nome ?')
idade =input('Em que ano você nasceu ?')
ano_base =2026
resposta =(ano_base-int(idade))
print(f'Seu nome é ! {nome}, E sua idade aproxinada é {resposta} !')
# Out:
# Seu nome é ! kiel, E sua idade aproxinada é 40 !

# %%
inteiro = 20

# %%
ponto_flutuante = 3.15

# %%
numero_complexo = 2+3j

# %%
print(type(inteiro))
print(type(ponto_flutuante))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(type(numero_complexo))
# Out:
# <class 'complex'>

# %% [markdown]
# # teste de str

# %%
nome="lucas"

# %%
cep="25615-070"

# %%
logradouro="""Rua Floriano Peixoto, 224
Bairro: Centro 
Cidade: Petropolis
Estado: Rj"""

# %%
print(logradouro)
# Out:
# Rua Floriano Peixoto, 224
# Bairro: Centro
# Cidade: Petropolis
# Estado: Rj

# %%
nome=input('Digite seu nome:')
ano_nasc=int(input(f'{nome},Digite o ano de nascimento:'))
idade=2026-ano_nasc
if idade >=18:
    print(f'{nome} ,Você é maior de idade!')
elif idade >=16:
    print(f'{nome} ,Você é adolecente !')
else:
   print('Você é menor de idade!')
# Out:
# kiel ,Você é adolecente !
